# %%
dbutils.widgets.combobox(name='Paramcombobox',defaultValue='apple',choices=['apple','banana','orange'],label='Fruits ComboBox')
dbutils.widgets.dropdown(name='Paramdropdown',defaultValue='apple',choices=['apple','banana','orange'],label='Fruits dropdown')
dbutils.widgets.multiselect(name='Parammultiselect',defaultValue='apple',choices=['apple','banana','orange'],label='Fruits Multiselect')
dbutils.widgets.text(name='Paramtext',defaultValue='apple',label='Fruits Textbox')

# %%
print('Combobox value ->',dbutils.widgets.get('Paramcombobox'))
print('dropdown value ->',dbutils.widgets.get('Paramdropdown'))
print('Multiselect value ->',dbutils.widgets.get('Parammultiselect'))
print('Text value ->',dbutils.widgets.get('Paramtext'))
# Out:
# Combobox value -> apple
# dropdown value -> apple
# Multiselect value -> apple
# Text value -> banana
