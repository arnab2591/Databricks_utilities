# %%
dbutils.help()
# Out:
# <div class = "ansiout">
# This module provides various utilities for users to interact with the rest of Databricks.
# ...

# %%
dbutils.fs.help()
# Out:
# <div class = "ansiout"><b>dbutils.fs</b> provides utilities for working with FileSystems. Most methods in
# this package can take either a DBFS path (e.g., "/foo" or "dbfs:/foo"), or
# another FileSystem URI.
#
# For more info about a method, use <b>dbutils.fs.help("methodName")</b>.
#
# In notebooks, you can also use the %fs shorthand to access DBFS. The %fs shorthand maps
# straightforwardly onto dbutils calls. For example, "%fs head --maxBytes=10000 /file/path"
# translates into "dbutils.fs.head("/file/path", maxBytes = 10000)".
# ...

# %%
dbutils.fs.help('cp')
# Out:
# <div class = "ansiout">/**<br /> * Copies a file or directory, possibly across FileSystems..<br /> * <br /> * Example: cp("/mnt/my-folder/a", "s3n://bucket/b")<br /> * <br /> * @param from FileSystem URI of the source file or directory<br /> * @param to FileSystem URI of the destination file or directory<br /> * @param recurse if true, all files and directories will be recursively copied<br /> * @return true if all files were successfully copied<br /> */<br /><b>cp(from: java.lang.String, to: java.lang.String, recurse: boolean = false): boolean</b></div><br />

# %%
dbutils.fs.cp('FileStore/emp_data/emp.csv','FileStore/emp_data_copy/emp_copy.csv')
# Out:
# Out[4]: True

# %%
dbutils.fs.head('FileStore/emp_data_copy/emp_copy.csv',25)
# Out:
# [Truncated to first 25 bytes]
# Out[1]: 'empid,empName,gender,sala'

# %%
dbutils.fs.mkdirs('/FileStore/data/')
# Out:
# Out[5]: True

# %%
dbutils.fs.rm('/FileStore/data/')
# Out:
# Out[3]: True

# %%
dbutils.fs.ls('/FileStore/')
# Out:
# Out[4]: [FileInfo(path='dbfs:/FileStore/emp_data/', name='emp_data/', size=0, modificationTime=1672583488000),
#  FileInfo(path='dbfs:/FileStore/emp_data_copy/', name='emp_data_copy/', size=0, modificationTime=1672737817000),
#  FileInfo(path='dbfs:/FileStore/tables/', name='tables/', size=0, modificationTime=1672582131000)]

# %%
dbutils.fs.mv('/FileStore/emp_data_copy/emp_copy.csv','/FileStore/data/emp_copy.csv')
# Out:
# Out[6]: True

# %%
dbutils.fs.put('/FileStore/data/emp_copy.csv','Hello Databricks!',True)
# Out:
# Wrote 17 bytes.
# Out[8]: True

# %%
dbutils.fs.head('/FileStore/data/emp_copy.csv')
# Out:
# Out[9]: 'Hello Databricks!'
